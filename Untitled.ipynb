# %%
import pandas as pd
from glob import glob

# %%
df_18=pd.read_csv(r'C:\Users\hp\Box\Azubi Africa\Project One\post-bap-LP1\startup_funding2018.csv')

# %%
df_18
# Out:
#      Company Name                                           Industry  \
# 0          Mombay         Food and Beverage, Food Delivery, Internet
# 1      AuthMetrik  B2B, Biometrics, Cyber Security, Fraud Detecti...
# 2       artbandhu  Digital Media, Internet, Media and Entertainme...
# 3         Wimoxez                                           Internet
# 4         Vizzbee  Artificial Intelligence, Drones, Navigation, P...
# ..            ...                                                ...
# 521          Myra                  Apps, Health Care, Pharmaceutical
# 522  Vogo Rentals  Last Mile Transportation, Railroad, Transporta...
# 523         Origo                                                  —
# 524       Chaayos                Food and Beverage, Restaurants, Tea
# 525      PetSutra                                         Veterinary
#
#                  Round/Series            Amount  \
# 0                        Seed              7500
# ...

# %%
df_18 ["Founded"] = " "
df_18 ["Investors"] = " " 
df_18 ["Founders"] = " "

df_18
# Out:
#      Company Name                                           Industry  \
# 0          Mombay         Food and Beverage, Food Delivery, Internet
# 1      AuthMetrik  B2B, Biometrics, Cyber Security, Fraud Detecti...
# 2       artbandhu  Digital Media, Internet, Media and Entertainme...
# 3         Wimoxez                                           Internet
# 4         Vizzbee  Artificial Intelligence, Drones, Navigation, P...
# ..            ...                                                ...
# 521          Myra                  Apps, Health Care, Pharmaceutical
# 522  Vogo Rentals  Last Mile Transportation, Railroad, Transporta...
# 523         Origo                                                  —
# 524       Chaayos                Food and Beverage, Restaurants, Tea
# 525      PetSutra                                         Veterinary
#
#                  Round/Series            Amount  \
# 0                        Seed              7500
# ...

# %%
df_18.rename(columns = {"Company Name":"Company/Brand","About Company":"What it does","Round/Series":"Stage",
                        "Industry":"Sector","Location":"HeadQuarter"}, inplace=True)

# %%
df_18.dtypes
# Out:
# Company/Brand     object
# Sector            object
# Stage             object
# Amount            object
# HeadQuarter       object
# What it does      object
# Unnamed: 6       float64
# Unnamed: 7       float64
# Founded           object
# Investors         object
# Founders          object
# dtype: object

# %%
df_18
# Out:
#     Company/Brand                                             Sector  \
# 0          Mombay         Food and Beverage, Food Delivery, Internet
# 1      AuthMetrik  B2B, Biometrics, Cyber Security, Fraud Detecti...
# 2       artbandhu  Digital Media, Internet, Media and Entertainme...
# 3         Wimoxez                                           Internet
# 4         Vizzbee  Artificial Intelligence, Drones, Navigation, P...
# ..            ...                                                ...
# 521          Myra                  Apps, Health Care, Pharmaceutical
# 522  Vogo Rentals  Last Mile Transportation, Railroad, Transporta...
# 523         Origo                                                  —
# 524       Chaayos                Food and Beverage, Restaurants, Tea
# 525      PetSutra                                         Veterinary
#
#                         Stage            Amount  \
# 0                        Seed              7500
# ...

# %%
Titles = list(df_18.columns)

# %%
Titles
# Out:
# ['Company/Brand',
#  'Sector',
#  'Stage',
#  'Amount',
#  'HeadQuarter',
#  'What it does',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Founded',
#  'Investors',
#  'Founders']

# %%
df_18.iloc[:,[0,6,4,1,5,8,7,3,2]]
# Out:
#     Company/Brand  Unnamed: 6                       HeadQuarter  \
# 0          Mombay         NaN        Mumbai, Maharashtra, India
# 1      AuthMetrik         NaN           Gurgaon, Haryana, India
# 2       artbandhu         NaN       Bangalore, Karnataka, India
# 3         Wimoxez         NaN  Hyderabad, Andhra Pradesh, India
# 4         Vizzbee         NaN     Bhopal, Madhya Pradesh, India
# ..            ...         ...                               ...
# 521          Myra         NaN       Bangalore, Karnataka, India
# 522  Vogo Rentals         NaN      Kormangala, Karnataka, India
# 523         Origo         NaN           Gurgaon, Haryana, India
# 524       Chaayos         NaN           New Delhi, Delhi, India
# 525      PetSutra         NaN           Gurgaon, Haryana, India
#
#                                                 Sector  \
# 0           Food and Beverage, Food Delivery, Internet
# 1    B2B, Biometrics, Cyber Security, Fraud Detecti...
# ...

# %%
df_18.to_csv('startup_funding2018final.csv', index=False)

# %%
#Reading the file path
Files = sorted(glob(r"C:\Users\hp\Box\Azubi Africa\Project One\post-bap-LP1\India Startup Funding\startup_funding*.csv"))
Files
# Out:
# ['C:\\Users\\hp\\Box\\Azubi Africa\\Project One\\post-bap-LP1\\India Startup Funding\\startup_funding2018final.csv',
#  'C:\\Users\\hp\\Box\\Azubi Africa\\Project One\\post-bap-LP1\\India Startup Funding\\startup_funding2019.csv',
#  'C:\\Users\\hp\\Box\\Azubi Africa\\Project One\\post-bap-LP1\\India Startup Funding\\startup_funding2020.csv',
#  'C:\\Users\\hp\\Box\\Azubi Africa\\Project One\\post-bap-LP1\\India Startup Funding\\startup_funding2021.csv']

# %%
#Combining the files in the folder. The for function is interating all the files in the folder
df = pd.concat([pd.read_csv(f) for f in Files], ignore_index=True)
df
# Out:
#      Company/Brand                                             Sector  \
# 0           Mombay         Food and Beverage, Food Delivery, Internet
# 1       AuthMetrik  B2B, Biometrics, Cyber Security, Fraud Detecti...
# 2        artbandhu  Digital Media, Internet, Media and Entertainme...
# 3          Wimoxez                                           Internet
# 4          Vizzbee  Artificial Intelligence, Drones, Navigation, P...
# ...            ...                                                ...
# 2874      Gigforce                              Staffing & Recruiting
# 2875        Vahdam                                   Food & Beverages
# 2876  Leap Finance                                 Financial Services
# 2877  CollegeDekho                                             EdTech
# 2878        WeRize                                 Financial Services
#
#              Stage     Amount($)                       HeadQuarter  \
# ...

# %%
#Removing the extra column in the data
df.drop(columns=['Unnamed: 9'], inplace = True)

# %%
#Checking the total number of duplicate information
df.duplicated().sum()
# Out:
# 23

# %%
df2 = df.drop_duplicates(keep='first')

# %%
df2
# Out:
#      Company/Brand                                             Sector  \
# 0           Mombay         Food and Beverage, Food Delivery, Internet
# 1       AuthMetrik  B2B, Biometrics, Cyber Security, Fraud Detecti...
# 2        artbandhu  Digital Media, Internet, Media and Entertainme...
# 3          Wimoxez                                           Internet
# 4          Vizzbee  Artificial Intelligence, Drones, Navigation, P...
# ...            ...                                                ...
# 2874      Gigforce                              Staffing & Recruiting
# 2875        Vahdam                                   Food & Beverages
# 2876  Leap Finance                                 Financial Services
# 2877  CollegeDekho                                             EdTech
# 2878        WeRize                                 Financial Services
#
#              Stage     Amount($)                       HeadQuarter  \
# ...

# %%
df2 = df2.astype({'Amount($)':'int'})
print(df2.dtypes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 df2 = df2.astype({'Amount($)':'int'})
#       2 print(df2.dtypes)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5898, in NDFrame.astype(self, dtype, copy, errors)
#    5896             res_col = col.copy() if copy else col
#    5897         else:
# -> 5898             res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    5899         results.append(res_col)
#    5901 elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    5902     # GH 18099/22869: columnwise conversion to extension dtype
#    5903     # GH 24704: use iloc to handle duplicate column names
#    5904     # TODO(EA2D): special case not needed with 2D EAs
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
# ...
